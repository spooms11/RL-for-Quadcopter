# %% [markdown]
# # 项目：指导四轴飞行器学会飞行
#
# 设计一个能够使四轴飞行器飞行的智能体，然后使用你选择的强化学习算法训练它！
#
# 请尝试运用你在这一单元中学到的知识，看看哪个方法效果最好，当然你也可以自己想出创新型方法并测试它们。
# ## 说明
#
# 请查看目录下的文件，以更好地了解项目结构。
#
# - `task.py`：在本文件中定义你的任务（环境）。
# - `agents/`：本文件夹中包含强化学习智能体。
#     - `policy_search.py`：我们为你提供了一个智能体模板。
#     - `agent.py`：在本文件中开发你的智能体。
# - `physics_sim.py`：本文件中包含四轴飞行器模拟器。**请勿修改本文件**。
#
# 在本项目中，你需要在 `task.py` 中定义你的任务。尽管我们为你提供了一个任务示例，来帮助你开始项目，但你也可以随意更改这个文件。在这个 notebook 中，你还将学习更多有关修改这个文件的知识。
#
# 你还需要在 `agent.py` 中设计一个强化学习智能体，来完成你选择的任务。
#
# 我们也鼓励你创建其他文件，来帮助你整理代码。比如，你也许可以通过定义一个 `model.py` 文件来定义其他你需要的神经网络结构。
#
# ## 控制四轴飞行器
#
# 在下方的代码中，我们提供了一个智能体示例，来示范如何使用模拟器来控制四轴飞行器。这个智能体比你在 notebook 中需要测试的智能体（在 `agents/policy_search.py` 中）更加简单！
#
# 这个智能体通过设置飞行器四个轴上的转速来控制飞行器。`Basic_Agent` 类中提供的智能体将会随机为四个轴指定动作。这四个速度将通过 `act` 方法以四个浮点数列表的形式返回。
#
# 在本项目中，你将在 `agents/agent.py` 中实现的智能体会以更加智能的方法进行指定的动作。

# %%
import random

class Basic_Agent():
    def __init__(self, task):
        self.task = task
    
    def act(self):
        new_thrust = random.gauss(450., 25.)
        return [new_thrust + random.gauss(0., 1.) for x in range(4)]

# %% [markdown]
# 运行下方代码，让智能体指定动作来控制四轴飞行器。
#
# 请随意更改我们提供的 `runtime`，`init_pose`，`init_velocities` 和 `init_angle_velocities` 值来更改四轴飞行器的初始条件。
#
# 下方的 `labels` 列表为模拟数据的注释。所有的信息都储存在 `data.txt` 文档中，并保存在 `results` 目录下。

# %%
# %load_ext autoreload
# %autoreload 2
#reload_ext autoreload

import csv
import numpy as np
from task import Task

# Modify the values below to give the quadcopter a different starting position.
runtime = 96.                                     # time limit of the episode
init_pose = np.array([0., 0., 10., 0., 0., 0.])  # initial pose
init_velocities = np.array([0., 0., 0.])         # initial velocities
init_angle_velocities = np.array([0., 0., 0.])   # initial angle velocities
file_output = 'data.txt'                         # file name for saved results

# Setup
task = Task(init_pose, init_velocities, init_angle_velocities, runtime)
agent = Basic_Agent(task)
done = False
labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x : [] for x in labels}

# Run the simulation, and save the results.
with open(file_output, 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(labels)
    while True:
        rotor_speeds = agent.act()
        _, _, done = task.step(rotor_speeds)
        to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(rotor_speeds)
        for ii in range(len(labels)):
            results[labels[ii]].append(to_write[ii])
        writer.writerow(to_write)
        if done:
            break

# %% [markdown]
# 在进行模拟时，请运行下方的代码来查看四轴飞行器的位置变化。

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(results['time'], results['x'], label='x')
plt.plot(results['time'], results['y'], label='y')
plt.plot(results['time'], results['z'], label='z')
plt.legend()
_ = plt.ylim()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# f:\app\anaconda2019\envs\reinforce-quadcopter\lib\site-packages\matplotlib\font_manager.py in <module>
#    1428         try:
# -> 1429             fontManager = pickle_load(_fmcache)
#    1430             if (not hasattr(fontManager, '_version') or
#
# f:\app\anaconda2019\envs\reinforce-quadcopter\lib\site-packages\matplotlib\font_manager.py in pickle_load(filename)
#     964     """
# --> 965     with open(filename, 'rb') as fh:
#     966         data = pickle.load(fh)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Hasee\\.matplotlib\\fontList.py3k.cache'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-0eb96883b22f> in <module>
# ----> 1 import matplotlib.pyplot as plt
#       2 get_ipython().run_line_magic('matplotlib', 'inline')
#       3
#       4 plt.plot(results['time'], results['x'], label='x')
#       5 plt.plot(results['time'], results['y'], label='y')
#
# f:\app\anaconda2019\envs\reinforce-quadcopter\lib\site-packages\matplotlib\pyplot.py in <module>
#      27 from cycler import cycler
#      28 import matplotlib
# ---> 29 import matplotlib.colorbar
#      30 from matplotlib import style
#      31 from matplotlib import _pylab_helpers, interactive
#
# f:\app\anaconda2019\envs\reinforce-quadcopter\lib\site-packages\matplotlib\colorbar.py in <module>
#      34 import matplotlib.collections as collections
#      35 import matplotlib.colors as colors
# ---> 36 import matplotlib.contour as contour
#      37 import matplotlib.cm as cm
#      38 import matplotlib.gridspec as gridspec
#
# f:\app\anaconda2019\envs\reinforce-quadcopter\lib\site-packages\matplotlib\contour.py in <module>
#      20 import matplotlib.colors as colors
#      21 import matplotlib.collections as mcoll
# ---> 22 import matplotlib.font_manager as font_manager
#      23 import matplotlib.text as text
#      24 import matplotlib.cbook as cbook
#
# f:\app\anaconda2019\envs\reinforce-quadcopter\lib\site-packages\matplotlib\font_manager.py in <module>
#    1437             raise
#    1438         except:
# -> 1439             _rebuild()
#    1440     else:
#    1441         _rebuild()
#
# f:\app\anaconda2019\envs\reinforce-quadcopter\lib\site-packages\matplotlib\font_manager.py in _rebuild()
#    1416         global fontManager
#    1417
# -> 1418         fontManager = FontManager()
#    1419
#    1420         if _fmcache:
#
# f:\app\anaconda2019\envs\reinforce-quadcopter\lib\site-packages\matplotlib\font_manager.py in __init__(self, size, weight)
#    1070         self.afmfiles = findSystemFonts(paths, fontext='afm') + \
#    1071             findSystemFonts(fontext='afm')
# -> 1072         self.afmlist = createFontList(self.afmfiles, fontext='afm')
#    1073         if len(self.afmfiles):
#    1074             self.defaultFont['afm'] = self.afmfiles[0]
#
# f:\app\anaconda2019\envs\reinforce-quadcopter\lib\site-packages\matplotlib\font_manager.py in createFontList(fontfiles, fontext)
#     583                     font = afm.AFM(fh)
#     584                 finally:
# --> 585                     fh.close()
#     586             except RuntimeError:
#     587                 verbose.report("Could not parse font file %s" % fpath)
#
# KeyboardInterrupt:

# %% [markdown]
# 下方代码输出了四轴飞行器的速度。

# %%
plt.plot(results['time'], results['x_velocity'], label='x_hat')
plt.plot(results['time'], results['y_velocity'], label='y_hat')
plt.plot(results['time'], results['z_velocity'], label='z_hat')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# 接下来，你可以绘制欧拉角 (Euler angles)（四轴飞行器围绕 $x$-，$y$- 和 $z$-轴的旋转）的图表，

# %%
plt.plot(results['time'], results['phi'], label='phi')
plt.plot(results['time'], results['theta'], label='theta')
plt.plot(results['time'], results['psi'], label='psi')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# 在绘制每个欧拉角的速度（每秒的弧度）图之前。

# %%
plt.plot(results['time'], results['phi_velocity'], label='phi_velocity')
plt.plot(results['time'], results['theta_velocity'], label='theta_velocity')
plt.plot(results['time'], results['psi_velocity'], label='psi_velocity')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# 最后，你可以使用下方代码来输出智能体选择的动作。

# %%
plt.plot(results['time'], results['rotor_speed1'], label='Rotor 1 revolutions / second')
plt.plot(results['time'], results['rotor_speed2'], label='Rotor 2 revolutions / second')
plt.plot(results['time'], results['rotor_speed3'], label='Rotor 3 revolutions / second')
plt.plot(results['time'], results['rotor_speed4'], label='Rotor 4 revolutions / second')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# 在指定任务之前，你需要在模拟器中衍生环境状态。运行下方代码来在模拟结束时输出以下变量值：
#
# - `task.sim.pose`：四周飞行器在 ($x,y,z$) 坐标系中的位置和欧拉角。
# - `task.sim.v`：四轴飞行器在 ($x,y,z$) 坐标系中的速度。
# - `task.sim.angular_v`：三个欧拉角的弧度/每秒。

# %%
# the pose, velocity, and angular velocity of the quadcopter at the end of the episode
print(task.sim.pose)
print(task.sim.v)
print(task.sim.angular_v)

# %% [markdown]
# 在 `task.py` 中的任务示例中，我们使用了四轴飞行器六个维度的动作来构建每个时间步的环境状态。然而，你也可以按照自己的意愿更改任务，你可以添加速度信息来扩大状态向量，也可以使用任何动作、速度和角速度的组合，并构造适用于你的任务的环境状态。
#
# ## 任务
#
# 在 `task.py` 中，我们为你提供了一个任务示例。请在新窗口中打开这个文件。
#
# 使用 `__init__()` 方法来初始化指定本任务所需的几个变量。
#
# - 模拟器作为 `PhysicsSim` 类（来自 `physics_sim.py` 文件）的示例进行初始化。
# - 受到 DDPG 论文中研究方法的启发，我们使用了重复调用动作的方法。对于智能体的每一个时间步，我们将利用 `action_repeats` 时间步来进行模拟。如果你并不熟悉这种方法，可以阅读 [DDPG 论文](https://arxiv.org/abs/1509.02971)的结论部分。
# - 我们设置了状态向量中每个分量的数值。在任务示例中，我们只设置了六个维度的动作信息。为了设定向量大小（`state_size`），我们必须考虑重复的动作。
# - 任务环境通常是一个四维动作空间，每个轴有一个输入（`action_size=4`）。你可以设置每个输入的最小值（`action_low`）和最大值（`action_high`）。
# - 我们在文件中提供的任务示例将使智能体达到目标位置。我们将目标位置设置为一个变量。
#
# `reset()` 方法将重置模拟器。每当阶段结束时，智能体都将调用此方法。你可以查看下方代码中的例子。
#
# `step()` 方法是最重要的一个方法。它将接收智能体选择的动作 `rotor_speeds`，并准备好下一个状态，同时返回给智能体。接着，你将通过 `get_reward()` 计算奖励值。当超过规定时间，或是四轴飞行器到达模拟器边缘时，这一阶段将视作结束。
#
# 接下来，你将学习如何测试这个任务中智能体的性能。
#
# ## 智能体
#
# `agents/policy_search.py` 文件中提供的智能体示例使用了非常简单的线性策略，将动作向量视作状态向量和矩阵权重的点积直接进行计算。接着，它通过添加一些高斯噪声来随机干扰参数，以产生不同的策略。根据每个阶段获得的平均奖励值（`score`），它将记录迄今为止发现的最佳参数集以及分数的变化状态，并据此调整比例因子来扩大或减少噪音。
#
# 请运行下方代码来查看任务示例中智能体的性能。

# %%
import sys
import pandas as pd
from agents.policy_search import PolicySearch_Agent
from task import Task

num_episodes = 200
target_pos = np.array([0., 0., 20.])
init_pose = np.array([0., 0., 0., 0., 0., 0.])
task = Task( target_pos=target_pos)
agent = PolicySearch_Agent(task) 
scores = []
for i_episode in range(1, num_episodes+1):
    state = agent.reset_episode() # start a new episode
    while True:
        action = agent.act(state) 
        next_state, reward, done = task.step(action)
        agent.step(reward, done)
        state = next_state
        if done:
            print("\rEpisode = {:4d}, score = {:7.3f} (best = {:7.3f}), noise_scale = {}".format(
                i_episode, agent.score, agent.best_score, agent.noise_scale), end="")  # [debug]
            scores.append(agent.score)
            break
            sys.stdout.flush()
plt.plot(scores, label='scores')
plt.legend()

# %% [markdown]
# 这个智能体的性能想必十分糟糕！现在轮到你出场了！
#
# ## 定义任务，设计并训练你的智能体！
#
# 修改 `task.py` 文件来指定你所选择的任务。如果你不确定选择什么任务，你可以教你的四轴飞行器起飞、盘旋、着陆或是达到指定位置。
#
#
# 在指定任务后，使用 `agents/policy_search.py` 中的智能体示例作为模板，来在 `agents/agent.py` 中定义你自己的智能体。你可以随意从智能体示例中借用你需要的元素，包括如何模块化你的代码（使用 `act()`，`learn()` 和 `reset_episode_vars()` 等辅助方法）。
#
# 请注意，你指定的第一个智能体和任务**极有可能**无法顺利进行学习。你将需要改进不同的超参数和奖励函数，直到你能够获得不错的结果。
#
# 在开发智能体的时候，你还需要关注它的性能。参考下方代码，建立一个机制来存储每个阶段的总奖励值。如果阶段奖励值在逐渐上升，说明你的智能体正在学习。

# %%
## TODO: Train your agent here.
import sys
import pandas as pd
from agents.DDPGai_priority import DDPG
from task import Task
import numpy as np
import csv
import random

num_episodes = 600
target_pos = np.array([0., 0., 20.])
task = Task(target_pos=target_pos)
agent = DDPG(task) 
scores = []

labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x : [] for x in labels}
file_output = 'data2.txt'                         # file name for saved results

with open(file_output, 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(labels)
    for i_episode in range(1, num_episodes+1):
        state = agent.reset_episode() # start a new episode
        score = 0.
        num = 0
        while True:
            action = agent.act(state) 
            next_state, reward, done = task.step(action)
            agent.step(action, reward, next_state, done)
            state = next_state
            score += reward
            num += 1
            if i_episode == num_episodes:
                to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(action)
                for ii in range(len(labels)):
                    results[labels[ii]].append(to_write[ii])
                writer.writerow(to_write)
            if done:
                score = score / num
                print("\rEpisode = {:4d}, score = {:7.3f}".format(
                    i_episode, score), end="")  # [debug]
                print('num',num)
                scores.append(score)        
                break
                sys.stdout.flush()
# Out:
# Using TensorFlow backend.
# F:\study\deep-learn\2.5-reinforcement\RL-Quadcopter-2-submit\agents\DDPGai_priority.py:422: RuntimeWarning: divide by zero encountered in double_scalars
#   ISWeights[i, 0] = np.power(prob/min_prob, -self.beta)
# Episode =    1, score = -52.493num 40
# Episode =    2, score = -55.435num 38
# Episode =    3, score = -70.354num 32
# Episode =    4, score = -103.594num 37
# Episode =    5, score = -58.858num 27
# Episode =    6, score = -64.300num 24
# Episode =    7, score = -66.991num 27
# Episode =    8, score = -58.894num 23
# Episode =    9, score = -57.385num 29
# Episode =   10, score = -60.167num 25
# Episode =   11, score = -58.824num 22
# Episode =   12, score = -53.186num 27
# Episode =   13, score = -64.095num 23
# Episode =   14, score = -57.847num 26
# Episode =   15, score = -53.156num 27
# Episode =   16, score = -56.843num 29
# Episode =   17, score = -66.766num 25
# Episode =   18, score = -63.306num 23
# Episode =   19, score = -61.753num 24
# Episode =   20, score = -60.436num 28
# Episode =   21, score = -64.495num 27
# Episode =   22, score = -61.837num 28
# Episode =   23, score = -56.618num 29
# Episode =   24, score = -66.045num 24
# Episode =   25, score = -61.305num 24
# Episode =   26, score = -68.142num 23
# Episode =   27, score = -63.600num 23
# Episode =   28, score = -62.154num 26
# Episode =   29, score = -68.382num 25
# Episode =   30, score = -61.601num 22
# Episode =   31, score = -65.933num 24
# Episode =   32, score = -63.517num 22
# Episode =   33, score = -59.212num 22
# Episode =   34, score = -61.356num 22
# Episode =   35, score = -62.696num 25
# Episode =   36, score = -61.678num 24
# Episode =   37, score = -60.054num 23
# Episode =   38, score = -58.806num 22
# Episode =   39, score = -63.023num 23
# Episode =   40, score = -52.108num 27
# Episode =   41, score = -67.226num 23
# Episode =   42, score = -62.403num 22
# Episode =   43, score = -62.269num 22
# Episode =   44, score = -58.528num 22
# Episode =   45, score = -65.122num 27
# Episode =   46, score = -61.294num 22
# Episode =   47, score = -62.057num 22
# Episode =   48, score = -62.048num 24
# Episode =   49, score = -60.917num 22
# Episode =   50, score = -62.976num 23
# Episode =   51, score = -60.175num 29
# Episode =   52, score = -62.786num 26
# Episode =   53, score = -69.963num 24
# Episode =   54, score = -64.077num 23
# Episode =   55, score = -60.960num 22
# Episode =   56, score = -63.742num 28
# Episode =   57, score = -63.351num 26
# Episode =   58, score = -54.208num 27
# Episode =   59, score = -67.877num 26
# Episode =   60, score = -59.625num 28
# Episode =   61, score = -57.096num 22
# Episode =   62, score = -62.041num 23
# Episode =   63, score = -57.966num 27
# Episode =   64, score = -67.121num 23
# Episode =   65, score = -65.721num 24
# Episode =   66, score = -65.539num 23
# Episode =   67, score = -57.439num 26
# Episode =   68, score = -67.872num 24
# Episode =   69, score = -62.170num 24
# Episode =   70, score = -69.199num 24
# Episode =   71, score = -58.101num 22
# Episode =   72, score = -64.242num 22
# Episode =   73, score = -60.246num 24
# Episode =   74, score = -60.494num 22
# Episode =   75, score = -59.551num 26
# Episode =   76, score = -63.157num 26
# Episode =   77, score = -62.203num 23
# Episode =   78, score = -58.339num 22
# Episode =   79, score = -45.448num 29
# Episode =   80, score = -68.375num 26
# Episode =   81, score = -69.648num 24
# Episode =   82, score = -63.590num 23
# Episode =   83, score = -56.382num 25
# Episode =   84, score = -66.445num 23
# Episode =   85, score = -64.978num 23
# Episode =   86, score = -64.693num 27
# Episode =  351, score = -66.041num 23
# Episode =  352, score = -58.175num 22
# Episode =  353, score = -60.321num 23
# Episode =  354, score = -65.809num 25
# Episode =  355, score = -60.182num 23
# Episode =  356, score = -52.271num 29
# Episode =  357, score = -62.622num 23
# Episode =  358, score = -64.715num 24
# Episode =  359, score = -61.097num 22
# Episode =  360, score = -67.071num 23
# Episode =  361, score = -48.333num 29
# Episode =  362, score = -65.394num 25
# Episode =  363, score = -63.233num 23
# Episode =  364, score = -66.163num 25
# Episode =  365, score = -60.240num 22
# Episode =  366, score = -62.413num 22
# Episode =  367, score = -67.312num 24
# Episode =  368, score = -61.274num 23
# Episode =  369, score = -58.917num 22
# Episode =  370, score = -64.201num 25
# Episode =  371, score = -60.382num 22
# Episode =  372, score = -62.118num 25
# Episode =  373, score = -57.268num 22

# %% [markdown]
# ## 绘制阶段奖励
#
# 请绘制智能体在每个阶段中获得的总奖励，这可以是单次运行的奖励值，也可以是多次运行的平均值。

# %%
## TODO: Plot the rewards.
plt.plot(scores, label='scores')
plt.legend()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(results['time'], results['x'], label='x')
plt.plot(results['time'], results['y'], label='y')
plt.plot(results['time'], results['z'], label='z')
plt.legend()
_ = plt.ylim()

# %%
plt.plot(results['time'], results['x_velocity'], label='x_hat')
plt.plot(results['time'], results['y_velocity'], label='y_hat')
plt.plot(results['time'], results['z_velocity'], label='z_hat')
plt.legend()
_ = plt.ylim()

# %%
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt

mpl.rcParams['legend.fontsize'] = 10

fig = plt.figure()
ax = fig.gca(projection='3d')

# Prepare arrays x, y, z
#theta = np.linspace(-4 * np.pi, 4 * np.pi, 100)
#z = np.linspace(-2, 2, 100)
#r = z**2 + 1
#x = r * np.sin(theta)
#y = r * np.cos(theta)
x = results['x']
y = results['y']
z = results['z']

ax.plot(x, y, z, label='parametric curve')
ax.legend()

plt.show()

# %% [markdown]
# ## 回顾
#
# **问题 1**：请描述你在 `task.py` 中指定的任务。你如何设计奖励函数？
#
# **回答**：任务是，无人机升空。reward = 50 - 300*(abs(self.sim.pose[:3] - self.target_pos)).sum() + 400*self.sim.linear_accel[2] + 400*self.sim.v[2] \
#         - .5*self.sim.linear_accel[1] - .5*self.sim.v[1] - .5*self.sim.linear_accel[0] - .5*self.sim.v[0]
#         reward = .001*reward
#         无人机距离目标越近，惩罚越少；无人机的速度稳定，惩罚少。
#
# **问题 2**：请简要描述你的智能体，你可以参考以下问题：
#
# - 你尝试了哪些学习算法？哪个效果最好？
# - 你最终选择了哪些超参数（比如 $\alpha$，$\gamma$，$\epsilon$ 等）？
# - 你使用了什么样的神经网络结构（如果有的话）？请说明层数、大小和激活函数等信息。
#
# **回答**：我用了DDPG（deep Deterministic Policy Gradient)]、回放缓冲区、神经网络算法。
#            我用了gamma=0.995，用于值评估。tau=0.01参数，用于权重软更新。
#            在Actor部分，我使用神经网络结构，2层，每层分别是64、64个节点，激活函数是relu，learning rate=0.0001 。在Critic部分，我使用神经网络结构，2层，每层分别是400、300个节点，激活函数是relu,learning rate = 0.001。
#
# **问题 3**：根据你绘制的奖励图，描述智能体的学习状况。
#
# - 学习该任务是简单还是困难？
# - 该学习曲线中是否存在循序渐进或急速上升的部分？
# - 该智能体的最终性能有多好？（比如最后十个阶段的平均奖励值）
#
# **回答**：该任务简单。
#            该学习曲线（绘制阶段奖励曲线）存在急速上升的部分。
#            我看了相关论文，修改了部分参数，但是该智能体不能让无人机飞起来。
#
# **问题 4**：请简要总结你的本次项目经历。你可以参考以下问题：
#
# - 本次项目中最困难的部分是什么？（例如开始项目、运行 ROS、绘制、特定的任务等。）
# - 关于四轴飞行器和你的智能体的行为，你是否有一些有趣的发现？
#
# **回答**： 本次项目中最困难的是给reward函数调节参数，以及一些神经网络的结构，还有reward scale。
